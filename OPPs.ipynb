# %% [markdown]
# Simple Explanation:
# Object-Oriented Programming (OOP) is a way of writing programs where we build everything around objects — just like things in the real world.
#
# Each object keeps its own data (information) and behavior (actions) together in one place.
#
# 💡 Example:
# Think about a Car in real life:
#
# Data (attributes): color, model, speed
#
# Behavior (methods): start(), stop(), accelerate()
#
# In OOP, we create a Car class as a blueprint, and then make car objects (like myCar, yourCar).
#
# ✨ Why we use OOP:
#
# Modularity: Code is divided into small parts (classes/objects)
#
# Reusability: You can reuse classes in other programs
#
# Scalability: Easy to add new features
#
# Maintainability: Easier to fix or update code
#
# 👉 In short:
#
# OOP helps you write programs that look and behave like real-world things — making them easier to understand, manage, and grow.

# %% [markdown]
# Class — Simple Definition
#
# A class is a blueprint or template for creating objects.<br>
# It defines what data (variables) and what actions (methods) an object will have.

# %%
class Car:
    def start(self):
        print("Car started")

# %% [markdown]
# Here:
#
# Car = class name
#
# start() = method (action that Car can do)
#
# You can now create objects (real cars) from this blueprint.

# %%
my_car = Car()
my_car.start()
# Out:
# Car started

# %% [markdown]
# Constructor (__init__) — Simple Definition
#
# A constructor is a special method inside a class that runs automatically when you create an object.
# It is used to initialize variables (give them starting values).

# %%
class Car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color

    def start(self):
        print(f"{self.brand} car started with color {self.color}.")

# %%
my_car = Car("Tesla", "Red")
my_car.start()
# Out:
# Tesla car started with color Red.

# %% [markdown]
# In short:
#
# Class → Blueprint (like plan of a car)
#
# Object → Real thing created from class (actual car)
#
# Constructor → Automatically sets the car’s details (brand, color) when it’s made

# %% [markdown]
# 🚗 What is an Object?
# 🧩 Simple Definition
#
# An object is a real instance of a class — it’s something created from the class blueprint.
#
# 👉 Think of:
#
# Class = Blueprint or plan
#
# Object = Actual thing built from that plan

# %%
class Car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color

    def start(self):
        print(f"{self.brand} car started with color {self.color}.")

# %%
car1 = Car("Tesla", "Red")
car2 = Car("BMW", "Black")

car1.start()
car2.start()
# Out:
# Tesla car started with color Red.
# BMW car started with color Black.

# %%
class Dog:
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed

    def bark(self):
        print(f"{self.name} is barking!")

dog1 = Dog("Tommy", "Labrador")
dog2 = Dog("Rocky", "German Shepherd")

dog1.bark()
dog2.bark()
# Out:
# Tommy is barking!
# Rocky is barking!

# %% [markdown]
# 🧩 What is Inheritance?
# ✅ Simple Definition
#
# Inheritance allows one class (child class) to reuse the properties and methods of another class (parent class).
#
# It means:
# ➡️ You don’t need to rewrite code again and again — just inherit it.

# %% [markdown]
# 🧠 Real-life Analogy
#
# 👨‍👩‍👧 Parents → Children
# A child inherits traits (like eyes, skin color, surname) from their parents.
# Similarly, a child class inherits code (variables and methods) from a parent class.

# %% [markdown]
# Example 1: Basic Inheritance

# %%
# Parent class
class Vehicle:
    def __init__(self, brand):
        self.brand = brand

    def start(self):
        print(f"{self.brand} started.")

# Child class
class Car(Vehicle):
    def drive(self):
        print(f"{self.brand} is driving on the road.")

# %%
car1 = Car("Tesla")
car1.start()   # Inherited from Vehicle
car1.drive()   # Defined in Car
# Out:
# Tesla started.
# Tesla is driving on the road.

# %% [markdown]
# Vehicle → Parent (base) class
#
# Car → Child (derived) class
#
# Car automatically inherits start() and __init__() from Vehicle
#
# You can still add new methods like drive() in Car

# %% [markdown]
# What does "Constructor Overriding" mean?
#
# When a child class defines its own constructor (__init__), it overrides (replaces) the parent’s constructor.
# 👉 The parent’s __init__() does not run automatically anymore — unless you explicitly call it using super().

# %% [markdown]
# Example to Understand This

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand = brand
        print("Vehicle constructor called")

class Car(Vehicle):
    def __init__(self, brand, color):
        self.color = color
        print("Car constructor called")

# %%
car1 = Car("BMW", "Black")
print(car1.color)
# Out:
# Car constructor called
# Black

# %% [markdown]
# Explanation
#
# The Car class has its own __init__().
#
# That means the parent’s constructor (Vehicle.__init__) is not called automatically.
#
# Only the child’s constructor runs — so the line “Vehicle constructor called” never appears

# %% [markdown]
# Now with super()
#
# If you still want the parent’s constructor to execute (to set the brand),
# you call it inside the child’s constructor using super()

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand = brand
        print("Vehicle constructor called")

class Car(Vehicle):
    def __init__(self, brand, color):
        super().__init__(brand)   # calls parent constructor
        self.color = color
        print("Car constructor called")

# %%
car1 = Car("BMW", "Black")
print(f"Brand: {car1.brand}, Color: {car1.color}")
# Out:
# Vehicle constructor called
# Car constructor called
# Brand: BMW, Color: Black

# %% [markdown]
# Step-by-step flow
#
# 1️⃣ Car("BMW", "Black") is called.
#
# 2️⃣ Python finds Car’s __init__ method.
#
# 3️⃣ Inside it, super().__init__(brand) calls Vehicle’s constructor.
#
# 4️⃣ Parent constructor sets self.brand = brand.
#
# 5️⃣ Control returns to Car constructor → sets self.color = color.
#
# 6️⃣ Object now has both attributes: brand and color.

# %% [markdown]
# 🧩 What is Polymorphism?
# ✅ Simple Definition
#
# Polymorphism means “many forms” — the same function or method name can behave differently depending on which object is calling it.
#
# 🧠 In simple words:
#
# A single method name can perform different actions based on the object type that uses it.

# %% [markdown]
# 💡 Real-Life Analogy
#
# Think of the word “drive” 🚗🚲🚚
#
# A Car drives on the road.
#
# A Boat drives (sails) on water.
#
# A Plane drives (flies) in the air.
#
# Same action “drive”, but different behavior — depending on the vehicle.
# That’s polymorphism!

# %% [markdown]
# Example 1: Same Method, Different Class Behavior

# %%
class Car:
    def start(self):
        print("Car started with a key.")

class Bike:
    def start(self):
        print("Bike started with a kick.")

# %%
for vehicle in (Car(), Bike()):
    vehicle.start()    # same method name, different behavior
# Out:
# Car started with a key.
# Bike started with a kick.

# %% [markdown]
# Explanation
#
# Both classes have a method named start().
#
# When Car object calls it → runs Car’s version.
#
# When Bike object calls it → runs Bike’s version.
# 👉 The method name is same, but the behavior changes — many forms of one function.

# %% [markdown]
# 🧩 Example 2: Polymorphism with Inheritance
#
# Polymorphism becomes more powerful when used with inheritance.

# %%
class Animal:
    def sound(self):
        print("Animal makes sound")

class Dog(Animal):
    def sound(self):
        print("Dog barks")

class Cat(Animal):
    def sound(self):
        print("Cat meows")

# %%
animals = [Dog(), Cat(), Animal()]

for a in animals:
    a.sound()
# Out:
# Dog barks
# Cat meows
# Animal makes sound

# %% [markdown]
# One-line Summary
#
# 🔹 Polymorphism = one name, many behaviors
# It makes code flexible, reusable, and more natural to understand.

# %% [markdown]
# 🧩 What is Abstraction?
# ✅ Simple Definition
#
# Abstraction means hiding complex details and showing only the necessary features to the user.
#
# You don’t need to know how something works internally — just what it does.

# %% [markdown]
# In Simple Words
#
# Abstraction helps us focus on what an object does, instead of how it does it.

# %% [markdown]
# 💡 Real-Life Example
#
# Think about driving a car 🚗
#
# When you drive:
#
# You press the accelerator to move forward,
#
# You press brakes to stop,
#
# You turn the steering wheel to change direction.
#
# Do you know how fuel burns inside the engine or how the brake system applies friction?
# ❌ No.
# Because those complex details are hidden (abstracted).
# You just use the simple interface — accelerator, brake, steering.
#
# That’s abstraction.

# %%
from abc import ABC, abstractmethod

class Payment(ABC):
    @abstractmethod
    def make_payment(self, amount):
        pass

class CreditCardPayment(Payment):
    def make_payment(self, amount):
        print(f"Paid ₹{amount} using Credit Card")

class UpiPayment(Payment):
    def make_payment(self, amount):
        print(f"Paid ₹{amount} using UPI")

# User only uses the interface
p1 = CreditCardPayment()
p2 = UpiPayment()

p1.make_payment(500)
p2.make_payment(300)
# Out:
# Paid ₹500 using Credit Card
# Paid ₹300 using UPI

# %% [markdown]
# What’s abstracted?
#
# You don’t see how transaction processing, encryption, or authentication work.
#
# You only use one method — make_payment() — to make it happen.

# %% [markdown]
# 🧠 What is Encapsulation?
#
# Encapsulation means binding (or wrapping) both the data (variables) and the functions (methods) that operate on that data into a single unit — a class.
#
# It also means restricting direct access to some of the class’s data to protect it from being modified accidentally or wrongly.

# %% [markdown]
# 🧩 Why Encapsulation?
#
# Encapsulation provides:
#
# Data protection → Prevent others from changing values directly.
#
# Controlled access → Only allow safe modification through specific methods.
#
# Modularity → Code is divided into well-defined units (classes).
#
# Ease of maintenance → If internal logic changes, outside code won’t break.

# %%
#Example 1 — Without Encapsulation
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

# Anyone can modify marks directly (unsafe)
s1 = Student("Anish", 85)
s1.marks = -50   # ❌ Invalid value
print(s1.marks)  # Output: -50 (wrong)
# Out:
# -50

# %%
#Example 2 — With Encapsulation (Data Protected)
class Student:
    def __init__(self, name, marks):
        self.__name = name     # private variable
        self.__marks = marks   # private variable

    # getter method
    def get_marks(self):
        return self.__marks

    # setter method with validation
    def set_marks(self, marks):
        if 0 <= marks <= 100:
            self.__marks = marks
        else:
            print("Invalid marks")

s1 = Student("Anish", 85)
print(s1.get_marks())  # ✅ Access via getter

s1.set_marks(95)       # ✅ Safe update
print(s1.get_marks())

s1.set_marks(150)      # ❌ Invalid marks
print(s1.get_marks())
# Out:
# 85
# 95
# Invalid marks
# 95

# %% [markdown]
# How Encapsulation Works Internally:
#
# Prefix __ (double underscore) before a variable → makes it private
#
# Private members cannot be accessed directly outside the class
#
# You use getter and setter methods to access or modify them safely

# %% [markdown]
# 🧱 Data Hiding vs Encapsulation:
# Concept	Meaning
# Encapsulation	Wrapping data and methods into one unit (class).
# Data Hiding	Restricting access to internal data using private variables.
#
# Data hiding is a part of encapsulation.
#
# 🧠 In Simple Words:
#
# Encapsulation =
#
# “Keep the data safe inside the class and allow others to interact with it only through proper doors (methods).”
